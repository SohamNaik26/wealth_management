# %%
import requests

# %%
x = requests.get('https://api.llama.fi/overview/fees/ethereum')

# %%
json = x.json()

# %%
protocal = json["protocols"]

# %%
print(protocal)
# Out:
# [{'defillamaId': '2695', 'name': 'SmarDex', 'disabled': False, 'displayName': 'SmarDex', 'module': 'SmarDex', 'category': 'Dexes', 'logo': 'https://icons.llamao.fi/icons/protocols/smardex.png', 'change_1d': 0, 'change_7d': 69.88, 'change_1m': -63.58, 'change_7dover7d': 70.97, 'change_30dover30d': 83.41, 'total24h': 177.57416757083195, 'total48hto24h': 177.57416757083195, 'total7d': 1658.6712783566963, 'total30d': 9048.92391501585, 'total14dto7d': 970.1731700768614, 'total60dto30d': 4933.727517537669, 'totalAllTime': 177.57416757083195, 'breakdown24h': {'ethereum': {'SmarDex': 177.57416757083195}}, 'chains': ['Ethereum'], 'protocolType': 'protocol', 'methodologyURL': 'https://github.com/DefiLlama/dimension-adapters/blob/master/fees/SmarDex', 'methodology': {'UserFees': '\nA minor fee is collected on each swap, functioning as trading fees.\nThe fees are set at 0.07% on Ethereum and 0.1% on other chains.\nOn other networks, fees may vary between different pairs and chains.\nRefer to htt
# ...

# %%
text1 = protocal[0]

# %%
print(text1)
# Out:
# {'defillamaId': '2695', 'name': 'SmarDex', 'disabled': False, 'displayName': 'SmarDex', 'module': 'SmarDex', 'category': 'Dexes', 'logo': 'https://icons.llamao.fi/icons/protocols/smardex.png', 'change_1d': 0, 'change_7d': 69.88, 'change_1m': -63.58, 'change_7dover7d': 70.97, 'change_30dover30d': 83.41, 'total24h': 177.57416757083195, 'total48hto24h': 177.57416757083195, 'total7d': 1658.6712783566963, 'total30d': 9048.92391501585, 'total14dto7d': 970.1731700768614, 'total60dto30d': 4933.727517537669, 'totalAllTime': 177.57416757083195, 'breakdown24h': {'ethereum': {'SmarDex': 177.57416757083195}}, 'chains': ['Ethereum'], 'protocolType': 'protocol', 'methodologyURL': 'https://github.com/DefiLlama/dimension-adapters/blob/master/fees/SmarDex', 'methodology': {'UserFees': '\nA minor fee is collected on each swap, functioning as trading fees.\nThe fees are set at 0.07% on Ethereum and 0.1% on other chains.\nOn other networks, fees may vary between different pairs and chains.\nRefer to http
# ...

# %%
list1 = text1['displayName']

# %%
print(list1)
# Out:
# SmarDex

# %%
list2 = text1['change_7d']

# %%
print(list2)
# Out:
# 69.88

# %%
list3 = text1["totalAllTime"]

# %%
print(list3)
# Out:
# 177.57416757083195

# %%
list4 = text1['dailyRevenue']

# %%
print(list4)
# Out:
# 126.83869112202282

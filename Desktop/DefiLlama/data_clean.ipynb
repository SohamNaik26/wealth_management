# %%
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/soham/Desktop/DefiLlama/data_clean.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/Users/soham/Desktop/DefiLlama/data_clean.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import requests
#
# ModuleNotFoundError: No module named 'requests'

# %%
x = requests.get('https://api.llama.fi/overview/fees/ethereum')

# %%
json = x.json()

# %%
protocal = json["protocols"]

# %%
print(protocal)
# Out:
# [{'defillamaId': '2695', 'name': 'SmarDex', 'disabled': False, 'displayName': 'SmarDex', 'module': 'SmarDex', 'category': 'Dexes', 'logo': 'https://icons.llamao.fi/icons/protocols/smardex.png', 'change_1d': 136.02, 'change_7d': 4.22, 'change_1m': 47.84, 'change_7dover7d': -11.18, 'change_30dover30d': 83.62, 'total24h': 463.18447134673687, 'total48hto24h': 196.24654830560445, 'total7d': 1679.2263225780052, 'total30d': 10637.827350982103, 'total14dto7d': 1890.6613605510925, 'total60dto30d': 5793.303872543276, 'total1y': 0, 'average1y': 0, 'totalAllTime': 69085.19607518148, 'breakdown24h': {'ethereum': {'SmarDex': 463.18447134673687}}, 'chains': ['Ethereum'], 'protocolType': 'protocol', 'methodologyURL': 'https://github.com/DefiLlama/dimension-adapters/blob/master/fees/SmarDex', 'methodology': {'UserFees': '\nA minor fee is collected on each swap, functioning as trading fees.\nThe fees are set at 0.07% on Ethereum and 0.1% on other chains.\nOn other networks, fees may vary between different pairs and chains.\nRefer to https://docs.smardex.io/overview/what-is-smardex/fees for detailed information.\n', 'Fees': '\nA minor fee is collected on each swap, functioning as trading fees.\nThe fees are set at 0.07% on Ethereum and 0.1% on other chains.\nOn other networks, fees may vary between different pairs and chains.\nRefer to https://docs.smardex.io/overview/what-is-smardex/fees for detailed information.\n', 'Revenue': '0.02% of each swap on Ethereum is collected for staking pool (SDEX holders that staked). On other chains, fees are collected for liquidity providers and fees may vary between different pairs and chains. Refer to https://docs.smardex.io/overview/what-is-smardex/fees for detailed information.', 'ProtocolRevenue': 'Protocol has no revenue.', 'HoldersRevenue': '0.02% of each swap on Ethereum is collected for staking pool (SDEX holders that staked). On other chains staking is not available and fees are collected for buybacks SDEX and burns.', 'SupplySideRevenue': '0.05% of each swap on Ethereum is collected for liquidity providers. On other chains, fees collected for liquidity providers and fees may vary between different pairs and chains. Refer to https://docs.smardex.io/overview/what-is-smardex/fees for detailed information.'}, 'latestFetchIsOk': True, 'dailyRevenue': 358.3765745251103, 'dailyUserFees': 463.18447134673687, 'dailyHoldersRevenue': None, 'dailyCreatorRevenue': None, 'dailySupplySideRevenue': 104.80789682162657, 'dailyProtocolRevenue': None, 'dailyBribesRevenue': None, 'dailyTokenTaxes': None, 'dailyFees': 463.18447134673687, 'holdersRevenue30d': None, 'totalVolume7d': 444.4421682536512, 'totalVolume30d': 313.29501651745267}, {'defillamaId': '2954', 'name': 'AirSwap', 'disabled': False, 'displayName': 'AirSwap', 'module': 'airswap', 'category': 'Dexes', 'logo': 'https://icons.llamao.fi/icons/protocols/airswap.jpg', 'change_1d': -27.54, 'change_7d': 25.45, 'change_1m': 507592.02, 'change_7dover7d': 56.07, 'change_30dover30d': 71.47, 'total24h': 1773.876350812622, 'total48hto24h': 2448.0149972041254, 'total7d': 15769.39165349141, 'total30d': 61384.64541847631, 'total14dto7d': 10104.157338193749, 'total60dto30d': 35798.61355465882, 'total1y': 0, 'average1y': 0, 'totalAllTime': None, 'breakdown24h': {'ethereum': {'airswap': 1773.876350812622}}, 'chains': ['Ethereum'], 'protocolType': 'protocol', 'methodologyURL': 'https://github.com/DefiLlama/dimension-adapters/blob/master/fees/airswap.ts', 'methodology': {'UserFees': 'Swap fees paid by users', 'Fees': 'Swap fees paid by users', 'Revenue': 'Percentage of swap fees going to treasury and/or token holders', 'ProtocolRevenue': 'Percentage of swap fees going to treasury', 'HoldersRevenue': 'Money going to governance token holders', 'SupplySideRevenue': 'Liquidity providers revenue'}, 'latestFetchIsOk': True, 'dailyRevenue': 1773.876350812622, 'dailyUserFees': 1773.876350812622, 'dailyHoldersRevenue': None, 'dailyCreatorRevenue': None, 'dailySupplySideRevenue': 0, 'dail ...

# %%
text1 = protocal[0]

# %%
print(text1)
# Out:
# {'defillamaId': '2695', 'name': 'SmarDex', 'disabled': False, 'displayName': 'SmarDex', 'module': 'SmarDex', 'category': 'Dexes', 'logo': 'https://icons.llamao.fi/icons/protocols/smardex.png', 'change_1d': 136.02, 'change_7d': 4.22, 'change_1m': 47.84, 'change_7dover7d': -11.18, 'change_30dover30d': 83.62, 'total24h': 463.18447134673687, 'total48hto24h': 196.24654830560445, 'total7d': 1679.2263225780052, 'total30d': 10637.827350982103, 'total14dto7d': 1890.6613605510925, 'total60dto30d': 5793.303872543276, 'total1y': 0, 'average1y': 0, 'totalAllTime': 69085.19607518148, 'breakdown24h': {'ethereum': {'SmarDex': 463.18447134673687}}, 'chains': ['Ethereum'], 'protocolType': 'protocol', 'methodologyURL': 'https://github.com/DefiLlama/dimension-adapters/blob/master/fees/SmarDex', 'methodology': {'UserFees': '\nA minor fee is collected on each swap, functioning as trading fees.\nThe fees are set at 0.07% on Ethereum and 0.1% on other chains.\nOn other networks, fees may vary between different pairs and chains.\nRefer to https://docs.smardex.io/overview/what-is-smardex/fees for detailed information.\n', 'Fees': '\nA minor fee is collected on each swap, functioning as trading fees.\nThe fees are set at 0.07% on Ethereum and 0.1% on other chains.\nOn other networks, fees may vary between different pairs and chains.\nRefer to https://docs.smardex.io/overview/what-is-smardex/fees for detailed information.\n', 'Revenue': '0.02% of each swap on Ethereum is collected for staking pool (SDEX holders that staked). On other chains, fees are collected for liquidity providers and fees may vary between different pairs and chains. Refer to https://docs.smardex.io/overview/what-is-smardex/fees for detailed information.', 'ProtocolRevenue': 'Protocol has no revenue.', 'HoldersRevenue': '0.02% of each swap on Ethereum is collected for staking pool (SDEX holders that staked). On other chains staking is not available and fees are collected for buybacks SDEX and burns.', 'SupplySideRevenue': '0.05% of each swap on Ethereum is collected for liquidity providers. On other chains, fees collected for liquidity providers and fees may vary between different pairs and chains. Refer to https://docs.smardex.io/overview/what-is-smardex/fees for detailed information.'}, 'latestFetchIsOk': True, 'dailyRevenue': 358.3765745251103, 'dailyUserFees': 463.18447134673687, 'dailyHoldersRevenue': None, 'dailyCreatorRevenue': None, 'dailySupplySideRevenue': 104.80789682162657, 'dailyProtocolRevenue': None, 'dailyBribesRevenue': None, 'dailyTokenTaxes': None, 'dailyFees': 463.18447134673687, 'holdersRevenue30d': None, 'totalVolume7d': 444.4421682536512, 'totalVolume30d': 313.29501651745267}

# %%
list1 = text1['displayName']

# %%
print(list1)
# Out:
# SmarDex

# %%
list2 = text1['change_7d']

# %%
print(list2)
# Out:
# 4.22

# %%
list3 = text1["totalAllTime"]

# %%
print(list3)
# Out:
# 69085.19607518148

# %%
list4 = text1['dailyRevenue']
